# %% [markdown]
# ##  Задача

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### а) Визначення події
#
# Припустимо що верстат № 2 виготовляє х виробів, Тоді верстат №1 2х виробів. Всього (n) з конвеєру сходить 3х товарів.
#
# Оскільки по умові задачі потрібно знайти ймовірність попадання виробу вищого гатунку P(A) = m/n де m - випадки сприятливі події, а n - загальна кількість випадків

# %% [markdown]
# m = V_1 + V_2

# %% [markdown]
# V_1 = 2x*0.6

# %% [markdown]
# V_2 = x*0.84

# %%
PA = (2*0.6+0.84)/3
PA
# Out:
# 0.68

# %% [markdown]
# ### Відпоідь - Ймовірність того що навмання взятий з ковеєра вищиго гатунку 0.68

# %% [markdown]
# ### б) Визначення події

# %% [markdown]
# Визначемо ймовірність виготовлення першим верстатом виробу вишого гатунку.(V1)

# %%
V1 = 2/3*0.6
V1
# Out:
# 0.39999999999999997

# %% [markdown]
# Згідно умовної ймовірності що виріб взятий з конвеєра вироб вищого гатунку, який вироблений першим верстатом дорівнює:

# %%
P=V1/PA
P
# Out:
# 0.588235294117647

# %% [markdown]
# ### Відпоідь - Ймовірність того що навмання взятий з ковеєра вироб вищиго гатунку, який вироблений першим верстатом 0.68
