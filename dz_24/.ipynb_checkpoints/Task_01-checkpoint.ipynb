# %% [markdown]
# ##  Задача

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Для вирішення даної задачі використаємо теорему Баєса

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# На початку висунемо  гіпотези та події:
# - Н1 -  документ з суттєвою похибкою склав перший економіст
# - Н2 -  документ з суттєвою похибкою склав другий економіст економіст
# - А1 -  документ  навмання витянутий під час перевірки  склав перший економіст
# - А2 -  документ навмання витянутий під час перевірки  склав другий  економіст

# %% [markdown]
# ###  Визначемо ймовірності навмання витянутого документа

# %%
Р_А1H1 = 40/100
Р_А2H2 = 60/100

# %% [markdown]
# Ймовірність зробити похибку першим та другим економістом задна по умові задачі

# %%
Р_Н1 = 0.1

# %%
Р_Н2 = 0.2

# %% [markdown]
# Підставляємо данні в формулу та обраховуємо

# %%
P_H1A1 = Р_А1H1 * Р_Н1 / (Р_А1H1 * Р_Н1 + Р_А2H2 * Р_Н2)
print('Ймоврність що документ з похибкою складений першим економістом',P_H1A1)
# Out:
# Ймоврність що документ з похибкою складений першим економістом 0.25000000000000006

# %%
P_H2A2 = Р_А2H2 * Р_Н2 / (Р_А1H1 * Р_Н1 + Р_А2H2 * Р_Н2)
print('Ймоврність що документ з похибкою складений другим економістом',P_H2A2)
# Out:
# Ймоврність що документ з похибкою складений другим економістом 0.75
