# %% [markdown]
# ### Задача

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Визначаэмо змінні

# %% [markdown]
# Змінну t визначаємо з таблиці Лапласа f(t) = y/2, -> f(t) = 0.475, -> t = 2.58

# %%
t = 2.58

# %%
σ = 3

# %%
δ = 0.6

# %%
n = t**2*σ**2/δ**2

# %%
print(f"Мінімальний об'єм вибірки має бути {round(n) + 1}") # Добавляю одиницю оскільки виходить 166.4 та заокруглюю до більшого.
# Out:
# Мінімальний об'єм вибірки має бути 167
